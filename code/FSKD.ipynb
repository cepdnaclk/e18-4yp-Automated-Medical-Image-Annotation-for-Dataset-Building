# %%
# !nvidia-smi
# Out:
# Tue Apr  9 06:00:19 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 545.23.06              Driver Version: 545.23.06    CUDA Version: 12.3     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA RTX A6000               On  | 00000000:15:00.0 Off |                  Off |
# | 80%   88C    P2             237W / 300W |  18815MiB / 49140MiB |     70%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
# !git clone https://github.com/wuzhe71/SCRN.git

# %%
# %cd SCRN

# %%
# !python3 test_SCRN.py

# %%
pwd
# Out:
# '/storage/scratch1/e18-4yp-medical-img-anno'

# %%
# !git clone https://github.com/AlanLuSun/Few-shot-keypoint-detection.git

# %%
# %cd Few-shot-keypoint-detection/
# Out:
# /storage/scratch1/e18-4yp-medical-img-anno/Few-shot-keypoint-detection

# %%
# !pip3 install tensorboardX

# %%
# !pip3 install einops

# %%
# import torch
# print(torch.__version__)

# %%
# !pip3 install opencv-python

# %%
# !python3 annotation_prepare.py

# %%
# !python3 main.py
# Out:
# Number of training images: 60 / valid: 60
# Number of training images: 44 / valid: 44
# Number of testing images: 60 / valid: 60
# Number of testing images: 60 / valid: 60
# /home/e18245/anaconda3/lib/python3.9/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/e18245/anaconda3/lib/python3.9/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Encoder initialized!
# Encoder(
#   (encoder_list): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
# ...

# %%
# !python eval.py
# Out:
# ^C
